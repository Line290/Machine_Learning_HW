# %%
import pandas as pd
from sklearn.cross_validation import KFold
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier


N_ESTIMATORS = 100
# No feature selection above basics. I'll just let the Random Forest do its thing.
IGNORE_LIST = ['id', 'profit', 'responded', 'pmonths']
CUTOFF = 0.22


def main():
    train = pd.read_csv('DataTraining.csv')
    test_original = pd.read_csv('DataPredict.csv')
    test = test_original.copy()

    train, train_factors = refactor(train)
    test, test_factors = refactor(test)

    train = fill_in_nan(train, 'day_of_week', N_ESTIMATORS)
    train = fill_in_nan(train, 'schooling', N_ESTIMATORS)
    train = fill_in_nan(train, 'custAge', N_ESTIMATORS)
    test = fill_in_nan(test, 'day_of_week', N_ESTIMATORS)
    test = fill_in_nan(test, 'schooling', N_ESTIMATORS)
    test = fill_in_nan(test, 'custAge', N_ESTIMATORS)

    prediction, forest = rf_predict(train, test, 'responded', N_ESTIMATORS, prob=True, ignore_list=IGNORE_LIST)

    test_original['market_to'] = [1 if p > CUTOFF else 0 for p in prediction]

    test_original.to_csv('data/testingCandidate_output.csv', index=False)


def k_split(df, k):
    """
    Split the training.csv set into k-folds, stored as a train, test dictionaries
    """
    train = {}
    test = {}
    kf = KFold(len(df), k, shuffle=True)
    i = 0
    for train_index, test_index in kf:
        train[i] = df.ix[train_index]
        test[i] = df.ix[test_index]
        i += 1
    return train, test


def refactor(df):
    """
    Make non-numerical data fields numerical with int factors
    Save the factor definitions in a dictionary for later
    """
    factors = {}
    for c in df.columns:
        if df[c].dtype not in [float, int]:
            factors[c] = {}
            i = 0
            for f in df[c].dropna().unique():
                factors[c][f] = i
                i += 1
    for c, d in factors.iteritems():
        for k, v in d.iteritems():
            df.ix[df[c] == k, c] = int(v)
    return df, factors


def rf_predict(train, test, col, n=100, prob=False, ignore_list=['id', 'profit', 'responded', 'pmonths']):
    """
    If you just want it to predict the field, leave prob=False. If you want the probability of 1 vs. 0, make it True.
    Don't fit on fields that still have nulls in them (or that are chosen to be ignored)
    Output the estimates for col in the test dataframe.
    """
    if prob:
        not_fit = ignore_list
        not_fit.extend(train.columns[train.isnull().sum() > 0])
        not_fit.extend(test.columns[test.isnull().sum() > 0])
        not_fit.append(col)
        not_fit = set(not_fit)
        forest = RandomForestClassifier(n_estimators=n)
        forest = forest.fit(train[[c for c in train.columns if c not in not_fit]], train[col])
        output = [x[1] for x in forest.predict_proba(test[[c for c in test.columns if c not in not_fit]])]
    else:
        not_fit = ignore_list
        not_fit.extend(train.columns[train.isnull().sum() > 0])
        not_fit.extend(test.columns[test.isnull().sum() > 0])
        not_fit.append(col)
        not_fit = set(not_fit)
        forest = RandomForestClassifier(n_estimators=n)
        forest = forest.fit(train[[c for c in train.columns if c not in not_fit]], train[col])
        output = forest.predict(test[[c for c in test.columns if c not in not_fit]])

    return output, forest


def fill_in_nan(df, col, n=100):
    """
    Use the rf_predict with prob=False to guess what missing values are.
    """
    output, forest = rf_predict(df[df[col].notnull()], df[df[col].isnull()], col, n, False)
    df.ix[df[col].isnull(), col] = output
    return df


def calc_profit(test, prediction, cutoff):
    """
    Use the profit function given to calculate profits for a certain cutoff on forest.predict_proba.
    This is what is to be optimized vs. cutoff choice.
    """
    test['prediction'] = prediction
    test.ix[test['profit'].isnull(), 'profit'] = -30
    return sum(test.ix[test['prediction'] >= cutoff, 'profit'])


# if __name__=="__main__":
#     main()
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## What value for CUTOFF should be chosen?

# %%
IGNORE_LIST = ['id', 'profit', 'responded', 'pmonths']

choice = {}

df_original = pd.read_csv('DataTraining.csv')
df = df_original.copy()
df, factors = refactor(df)
df = fill_in_nan(df, 'day_of_week', 100)
df = fill_in_nan(df, 'schooling', 100)
df = fill_in_nan(df, 'custAge', 100)

for iterations in range(100):
    train, test = k_split(df, 10)

    prediction = {}
    forest = {}
    profit = {}
    profit['cutoff'] = np.linspace(0, 1, 101)

    for i in train:
        prediction[i], forest[i] = rf_predict(train[i], test[i], 'responded', 100, prob=True, ignore_list=IGNORE_LIST)
        profit[i] = []
        for c in profit['cutoff']:
            profit[i].append(calc_profit(test[i], prediction[i], c))

    df_profit = pd.DataFrame(profit)
    df_profit.set_index('cutoff', inplace=True)

    maxc = 0
    for c in enumerate(df_profit.sum(axis=1)):
        maxc = max(maxc, c[1])
        if maxc == c[1]:
            cutoff_choice = df_profit.index[c[0]]
            highest_profit = c[1] / len(train)
#     print 'Best choice for cutoff : {}'.format(cutoff_choice)
#     print '  with an expected profit of ${} per fold'.format(highest_profit)

#     df_profit.plot()

    try:
        choice[cutoff_choice] += 1
    except:
        choice[cutoff_choice] = 1

print choice
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:66: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-922a9a09d8d7> in <module>()
#       6 df = df_original.copy()
#       7 df, factors = refactor(df)
# ----> 8 df = fill_in_nan(df, 'day_of_week', 100)
#       9 df = fill_in_nan(df, 'schooling', 100)
#      10 df = fill_in_nan(df, 'custAge', 100)
#
# <ipython-input-1-c721ce8f9030> in fill_in_nan(df, col, n)
#     100     Use the rf_predict with prob=False to guess what missing values are.
#     101     """
# --> 102     output, forest = rf_predict(df[df[col].notnull()], df[df[col].isnull()], col, n, False)
#     103     df.ix[df[col].isnull(), col] = output
#     104     return df
#
# <ipython-input-1-c721ce8f9030> in rf_predict(train, test, col, n, prob, ignore_list)
#      90         not_fit = set(not_fit)
#      91         forest = RandomForestClassifier(n_estimators=n)
# ---> 92         forest = forest.fit(train[[c for c in train.columns if c not in not_fit]], train[col])
#      93         output = forest.predict(test[[c for c in test.columns if c not in not_fit]])
#      94
#
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
#     275         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.pyc in _validate_y_class_weight(self, y)
#     469
#     470     def _validate_y_class_weight(self, y):
# --> 471         check_classification_targets(y)
#     472
#     473         y = np.copy(y)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/multiclass.pyc in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'unknown'

# %%
df_original = pd.read_csv('~/uptake/data/training.csv')
df = df_original.copy()
train, test = k_split(df, 2)
train = train[0]
test = test[0]

train, train_factors = refactor(train)
test, test_factors = refactor(test)

train = fill_in_nan(train, 'day_of_week', 100)
train = fill_in_nan(train, 'schooling', 100)
train = fill_in_nan(train, 'custAge', 100)
test = fill_in_nan(test, 'day_of_week', 100)
test = fill_in_nan(test, 'schooling', 100)
test = fill_in_nan(test, 'custAge', 100)

prediction, forest = rf_predict(train, test, 'responded', 100, prob=True, ignore_list=['id', 'profit', 'responded', 'pmonths', 'nr.employed', 'cons.conf.idx', 'cons.price.idx', 'emp.var.rate', 'month', 'contact'])

for i in np.linspace(0, 1, 101):
    profit = calc_profit(test, prediction, i)
    print '{} : {}'.format(i, profit)
# Out:
# 0.0 : -25904.0
# 0.01 : -23201.0
# 0.02 : -17614.0
# 0.03 : -7341.0
# 0.04 : -37.0
# 0.05 : 7003.0
# 0.06 : 13758.0
# 0.07 : 19837.0
# 0.08 : 23720.0
# 0.09 : 26966.0
# 0.1 : 27709.0
# 0.11 : 29350.0
# 0.12 : 31128.0
# 0.13 : 32689.0
# 0.14 : 33767.0
# 0.15 : 35055.0
# 0.16 : 35393.0
# 0.17 : 34843.0
# 0.18 : 34975.0
# 0.19 : 34202.0
# 0.2 : 33874.0
# 0.21 : 33815.0
# 0.22 : 33877.0
# 0.23 : 33249.0
# 0.24 : 33457.0
# 0.25 : 33493.0
# 0.26 : 32605.0
# 0.27 : 31794.0
# 0.28 : 30743.0
# 0.29 : 30289.0
# 0.3 : 28730.0
# 0.31 : 27890.0
# 0.32 : 27004.0
# 0.33 : 26807.0
# 0.34 : 26419.0
# 0.35 : 25815.0
# 0.36 : 25875.0
# 0.37 : 25203.0
# 0.38 : 25112.0
# 0.39 : 24582.0
# 0.4 : 23601.0
# 0.41 : 22875.0
# 0.42 : 22935.0
# 0.43 : 22259.0
# 0.44 : 21545.0
# 0.45 : 20840.0
# 0.46 : 20451.0
# 0.47 : 19570.0
# 0.48 : 19600.0
# 0.49 : 18940.0
# 0.5 : 18176.0
# 0.51 : 17842.0
# 0.52 : 17283.0
# 0.53 : 16970.0
# 0.54 : 16942.0
# 0.55 : 16331.0
# 0.56 : 15735.0
# 0.57 : 14656.0
# 0.58 : 14656.0
# 0.59 : 14334.0
# 0.6 : 13483.0
# 0.61 : 13391.0
# 0.62 : 13301.0
# 0.63 : 12616.0
# 0.64 : 12058.0
# 0.65 : 10464.0
# 0.66 : 9739.0
# 0.67 : 8766.0
# 0.68 : 8722.0
# 0.69 : 7991.0
# 0.7 : 6791.0
# 0.71 : 6297.0
# 0.72 : 5405.0
# 0.73 : 4634.0
# 0.74 : 4187.0
# 0.75 : 3624.0
# 0.76 : 3624.0
# 0.77 : 3501.0
# 0.78 : 3337.0
# 0.79 : 3318.0
# 0.8 : 3165.0
# 0.81 : 3042.0
# 0.82 : 2397.0
# 0.83 : 1748.0
# 0.84 : 1748.0
# 0.85 : 1479.0
# 0.86 : 1414.0
# 0.87 : 882.0
# 0.88 : 882.0
# 0.89 : 485.0
# 0.9 : 485.0
# 0.91 : 515.0
# 0.92 : 297.0
# 0.93 : 148.0
# 0.94 : 0
# 0.95 : 0
# 0.96 : 0
# 0.97 : 0
# 0.98 : 0
# 0.99 : 0
# 1.0 : 0

# %%
df_original = pd.read_csv('~/uptake/data/training.csv')
df = df_original.copy()
train, test = k_split(df, 2)
train = train[0]
test = test[0]

train, train_factors = refactor(train)
test, test_factors = refactor(test)

train = fill_in_nan(train, 'day_of_week', 100)
train = fill_in_nan(train, 'schooling', 100)
train = fill_in_nan(train, 'custAge', 100)
test = fill_in_nan(test, 'day_of_week', 100)
test = fill_in_nan(test, 'schooling', 100)
test = fill_in_nan(test, 'custAge', 100)

prediction, forest = rf_predict(train, test, 'responded', 100, prob=True, ignore_list=['id', 'profit', 'responded', 'pmonths'])

for i in np.linspace(0, 1, 101):
    profit = calc_profit(test, prediction, i)
    print '{} : {}'.format(i, profit)
# Out:
# 0.0 : -27723.0
# 0.01 : -24767.0
# 0.02 : -20171.0
# 0.03 : -13685.0
# 0.04 : -7408.0
# 0.05 : -929.0
# 0.06 : 5477.0
# 0.07 : 10258.0
# 0.08 : 16080.0
# 0.09 : 18720.0
# 0.1 : 22615.0
# 0.11 : 25775.0
# 0.12 : 27415.0
# 0.13 : 30960.0
# 0.14 : 32872.0
# 0.15 : 33922.0
# 0.16 : 34860.0
# 0.17 : 35850.0
# 0.18 : 36203.0
# 0.19 : 37054.0
# 0.2 : 36957.0
# 0.21 : 37636.0
# 0.22 : 36550.0
# 0.23 : 35704.0
# 0.24 : 36355.0
# 0.25 : 36187.0
# 0.26 : 36153.0
# 0.27 : 35700.0
# 0.28 : 34553.0
# 0.29 : 34536.0
# 0.3 : 33364.0
# 0.31 : 32595.0
# 0.32 : 31231.0
# 0.33 : 30847.0
# 0.34 : 30537.0
# 0.35 : 28415.0
# 0.36 : 28415.0
# 0.37 : 26535.0
# 0.38 : 24963.0
# 0.39 : 24030.0
# 0.4 : 23505.0
# 0.41 : 20516.0
# 0.42 : 20516.0
# 0.43 : 19784.0
# 0.44 : 19595.0
# 0.45 : 18910.0
# 0.46 : 16662.0
# 0.47 : 15173.0
# 0.48 : 15173.0
# 0.49 : 14770.0
# 0.5 : 13398.0
# 0.51 : 12415.0
# 0.52 : 11410.0
# 0.53 : 10243.0
# 0.54 : 9125.0
# 0.55 : 8141.0
# 0.56 : 7086.0
# 0.57 : 4923.0
# 0.58 : 4923.0
# 0.59 : 3571.0
# 0.6 : 3381.0
# 0.61 : 3224.0
# 0.62 : 2795.0
# 0.63 : 2612.0
# 0.64 : 2092.0
# 0.65 : 2062.0
# 0.66 : 1320.0
# 0.67 : 1376.0
# 0.68 : 764.0
# 0.69 : 306.0
# 0.7 : 102.0
# 0.71 : 102.0
# 0.72 : -72.0
# 0.73 : -12.0
# 0.74 : 15.0
# 0.75 : 15.0
# 0.76 : -137.0
# 0.77 : -137.0
# 0.78 : -137.0
# 0.79 : -137.0
# 0.8 : -137.0
# 0.81 : -137.0
# 0.82 : 0
# 0.83 : 0
# 0.84 : 0
# 0.85 : 0
# 0.86 : 0
# 0.87 : 0
# 0.88 : 0
# 0.89 : 0
# 0.9 : 0
# 0.91 : 0
# 0.92 : 0
# 0.93 : 0
# 0.94 : 0
# 0.95 : 0
# 0.96 : 0
# 0.97 : 0
# 0.98 : 0
# 0.99 : 0
# 1.0 : 0

# %% [markdown]
# ## Dumb feature selection
# I'd probably like more to do a logistic regression to pick out the fields that are most predictive, but this will do.

# %%
import itertools

df_original = pd.read_csv('~/uptake/data/training.csv')
df = df_original.copy()
df, factors = refactor(df)
df = fill_in_nan(df, 'day_of_week', 100)
df = fill_in_nan(df, 'schooling', 100)
df = fill_in_nan(df, 'custAge', 100)
train, test = k_split(df, 2)

ignore_list = ['id', 'profit', 'responded']

selector = {}
# combo = itertools.combinations([c for c in df.columns if c not in ignore_list], 2)
for j in range(1, 7):
    combo = itertools.combinations(['cons.conf.idx', 'cons.price.idx', 'default', 'month', 'schooling', 'previous'], j)
    for c in combo:
        il = ignore_list[:]
        il.extend(c)
        print 'ignore_list : {}'.format(il)

        prediction = {}
        forest = {}
        profit = {}
        profit['cutoff'] = np.linspace(0, 1, 101)

        for t in train:
            prediction[t], forest[t] = rf_predict(train[t], test[t], 'responded', 100, prob=True, ignore_list=il)
            profit[t] = []
            for co in profit['cutoff']:
                profit[t].append(calc_profit(test[t], prediction[t], co))

        df_profit = pd.DataFrame(profit)
        df_profit.set_index('cutoff', inplace=True)

        maxc = 0
        for x in enumerate(df_profit.sum(axis=1)):
            maxc = max(maxc, x[1])
            if maxc == x[1]:
                cutoff_choice = df_profit.index[x[0]]
                highest_profit = x[1] / len(train)

        for i in c:
            try:
                selector[i] += highest_profit
            except:
                selector[i] = highest_profit
        print 'Best choice for cutoff : {}'.format(cutoff_choice)
        print '  with an expected profit of ${} per fold'.format(highest_profit)  
        print ''
# Out:
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx']
# Best choice for cutoff : 0.25
#   with an expected profit of $34058.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx']
# Best choice for cutoff : 0.23
#   with an expected profit of $34670.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default']
# Best choice for cutoff : 0.21
#   with an expected profit of $33241.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'month']
# Best choice for cutoff : 0.23
#   with an expected profit of $33696.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'schooling']
# Best choice for cutoff : 0.2
#   with an expected profit of $33362.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $33515.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx']
# Best choice for cutoff : 0.2
#   with an expected profit of $33630.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default']
# Best choice for cutoff : 0.19
#   with an expected profit of $34640.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'month']
# Best choice for cutoff : 0.2
#   with an expected profit of $33345.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'schooling']
# Best choice for cutoff : 0.22
#   with an expected profit of $34263.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'previous']
# Best choice for cutoff : 0.2
#   with an expected profit of $34455.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default']
# Best choice for cutoff : 0.23
#   with an expected profit of $34671.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'month']
# Best choice for cutoff : 0.24
#   with an expected profit of $33438.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'schooling']
# Best choice for cutoff : 0.24
#   with an expected profit of $33470.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'previous']
# Best choice for cutoff : 0.2
#   with an expected profit of $34472.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'month']
# Best choice for cutoff : 0.18
#   with an expected profit of $34308.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'schooling']
# Best choice for cutoff : 0.23
#   with an expected profit of $33858.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $33823.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'month', 'schooling']
# Best choice for cutoff : 0.22
#   with an expected profit of $33217.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'month', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $33899.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'schooling', 'previous']
# Best choice for cutoff : 0.2
#   with an expected profit of $32938.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default']
# Best choice for cutoff : 0.19
#   with an expected profit of $34457.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'month']
# Best choice for cutoff : 0.25
#   with an expected profit of $33255.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'schooling']
# Best choice for cutoff : 0.22
#   with an expected profit of $34600.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'previous']
# Best choice for cutoff : 0.21
#   with an expected profit of $34114.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'month']
# Best choice for cutoff : 0.2
#   with an expected profit of $33249.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'schooling']
# Best choice for cutoff : 0.23
#   with an expected profit of $33605.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'previous']
# Best choice for cutoff : 0.23
#   with an expected profit of $34344.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'month', 'schooling']
# Best choice for cutoff : 0.2
#   with an expected profit of $33072.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'month', 'previous']
# Best choice for cutoff : 0.17
#   with an expected profit of $33826.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'schooling', 'previous']
# Best choice for cutoff : 0.2
#   with an expected profit of $32973.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'month']
# Best choice for cutoff : 0.18
#   with an expected profit of $32490.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'schooling']
# Best choice for cutoff : 0.2
#   with an expected profit of $33658.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $34446.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'month', 'schooling']
# Best choice for cutoff : 0.21
#   with an expected profit of $33018.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'month', 'previous']
# Best choice for cutoff : 0.25
#   with an expected profit of $32837.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'schooling', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $33681.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'month', 'schooling']
# Best choice for cutoff : 0.21
#   with an expected profit of $32844.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'month', 'previous']
# Best choice for cutoff : 0.21
#   with an expected profit of $33755.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'schooling', 'previous']
# Best choice for cutoff : 0.25
#   with an expected profit of $34311.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.21
#   with an expected profit of $34063.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'month']
# Best choice for cutoff : 0.19
#   with an expected profit of $32936.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'schooling']
# Best choice for cutoff : 0.2
#   with an expected profit of $33125.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'previous']
# Best choice for cutoff : 0.18
#   with an expected profit of $33943.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'month', 'schooling']
# Best choice for cutoff : 0.26
#   with an expected profit of $32695.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'month', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $32378.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'schooling', 'previous']
# Best choice for cutoff : 0.21
#   with an expected profit of $33774.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'month', 'schooling']
# Best choice for cutoff : 0.2
#   with an expected profit of $33495.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'month', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $33965.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'schooling', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $33237.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $33445.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'month', 'schooling']
# Best choice for cutoff : 0.18
#   with an expected profit of $33317.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'month', 'previous']
# Best choice for cutoff : 0.2
#   with an expected profit of $32919.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'schooling', 'previous']
# Best choice for cutoff : 0.25
#   with an expected profit of $33361.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $33801.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'default', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.23
#   with an expected profit of $33032.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'month', 'schooling']
# Best choice for cutoff : 0.24
#   with an expected profit of $32748.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'month', 'previous']
# Best choice for cutoff : 0.18
#   with an expected profit of $33261.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'schooling', 'previous']
# Best choice for cutoff : 0.21
#   with an expected profit of $32983.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.23
#   with an expected profit of $32276.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'default', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.16
#   with an expected profit of $33350.5 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.price.idx', 'default', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.22
#   with an expected profit of $33301.0 per fold
#
# ignore_list : ['id', 'profit', 'responded', 'cons.conf.idx', 'cons.price.idx', 'default', 'month', 'schooling', 'previous']
# Best choice for cutoff : 0.19
#   with an expected profit of $32911.5 per fold

# %%
selector
# Out:
# {'cons.conf.idx': 1072417.5,
#  'cons.price.idx': 1070645.5,
#  'default': 1073592.5,
#  'month': 1064150.0,
#  'previous': 1073397.0,
#  'schooling': 1067791.5}

# %%
selector
# Out:
# {'campaign': 691211.5,
#  'cons.conf.idx': 713905.0,
#  'cons.price.idx': 713567.5,
#  'contact': 699623.5,
#  'custAge': 704061.0,
#  'day_of_week': 681371.0,
#  'default': 712717.0,
#  'emp.var.rate': 708640.5,
#  'euribor3m': 687252.5,
#  'housing': 708502.0,
#  'loan': 705265.5,
#  'marital': 696958.5,
#  'month': 711294.5,
#  'nr.employed': 707388.5,
#  'pastEmail': 708919.0,
#  'pdays': 707353.5,
#  'pmonths': 708494.0,
#  'poutcome': 707629.0,
#  'previous': 710983.0,
#  'profession': 706888.5,
#  'schooling': 713167.5}

# %% [markdown]
# ## Smarter feature selection
# Still not convinced this is wonderful, but it helps optimize, maybe. Ignore those with P < 0.01.

# %%
import statsmodels.api as sm

IGNORE_LIST = ['id', 'profit', 'responded']

logit = sm.Logit(df['responded'].astype(int), df[[c for c in df.columns if c not in IGNORE_LIST]].astype(float))
result = logit.fit()

print result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.278529
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              responded   No. Observations:                 8238
# Model:                          Logit   Df Residuals:                     8217
# Method:                           MLE   Df Model:                           20
# Date:                Mon, 08 Jun 2015   Pseudo R-squ.:                  0.2088
# Time:                        19:07:39   Log-Likelihood:                -2294.5
# converged:                       True   LL-Null:                       -2899.9
#                                         LLR p-value:                3.662e-244
# ==================================================================================
#                      coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# custAge            0.0039      0.004      1.070      0.284        -0.003     0.011
# profession         0.0009      0.012      0.080      0.937        -0.022     0.024
# marital           -0.0713      0.048     -1.499      0.134        -0.165     0.022
# schooling         -0.0026      0.021     -0.121      0.904        -0.044     0.039
# default           -0.3199      0.127     -2.515      0.012        -0.569    -0.071
# housing            0.0099      0.073      0.134      0.893        -0.134     0.154
# loan               0.0991      0.101      0.980      0.327        -0.099     0.297
# contact           -0.6814      0.115     -5.936      0.000        -0.906    -0.456
# month             -0.0799      0.018     -4.442      0.000        -0.115    -0.045
# day_of_week       -0.0601      0.028     -2.180      0.029        -0.114    -0.006
# campaign          -0.0324      0.020     -1.586      0.113        -0.072     0.008
# pdays             -0.0093      0.034     -0.275      0.784        -0.076     0.057
# previous          -0.2305      0.127     -1.817      0.069        -0.479     0.018
# poutcome          -0.2974      0.155     -1.913      0.056        -0.602     0.007
# emp.var.rate      -0.4359      0.120     -3.646      0.000        -0.670    -0.202
# cons.price.idx     0.4901      0.056      8.736      0.000         0.380     0.600
# cons.conf.idx      0.0259      0.009      2.820      0.005         0.008     0.044
# euribor3m          0.1802      0.138      1.307      0.191        -0.090     0.450
# nr.employed       -0.0087      0.001     -7.754      0.000        -0.011    -0.006
# pmonths            0.0068      0.034      0.201      0.840        -0.059     0.073
# pastEmail         -0.0579      0.036     -1.626      0.104        -0.128     0.012
# ==================================================================================

# %% [markdown]
# ## If I were to care about just getting 'responded' right, how would I pick cutoff?

# %%
cutoffs = np.linspace(0, 1, 101)
alpha = []
beta = []
distance = []
for c in cutoffs:
    alpha.append(sum(test[0].ix[test[0]['prediction'] >= c, 'responded'] == 0))
    beta.append(sum(test[0].ix[test[0]['prediction'] < c, 'responded'] == 1))
    distance.append(np.sqrt(alpha[-1] ** 2 + beta[-1] ** 2))
    
params = pd.DataFrame({'cutoffs': cutoffs,
                       'alpha': alpha,
                       'beta': beta,
                       'distance': distance})

plt.plot(params['alpha'], params['beta'])
plt.show()

# %% [markdown]
# ##What value of n_estimators makes sense?

# %%
col = 'schooling'

for fold in train:
    print 'fold = {}'.format(fold)
    print ''
    for n in [5, 10, 50, 100, 500, 1000]:
        output = rf_predict(train[fold][train[fold][col].notnull()], test[fold][test[fold][col].notnull()], col, n)
        print 'n = {}'.format(n)
        print sum(test[fold].ix[test[fold][col].notnull(), col].values == output)
        print len(test[fold][test[fold][col].notnull()]) - sum(test[fold].ix[test[fold][col].notnull(), col].values == output)
        print sum(test[fold].ix[test[fold][col].notnull(), col].values == output) / len(test[fold][test[fold][col].notnull()])
        print ''
# Out:
# fold = 0
#
# n = 5
# 1110
# 1817
# 0.379227878374
#
# n = 10
# 1121
# 1806
# 0.382985992484
#
# n = 50
# 1184
# 1743
# 0.404509736932
#
# n = 100
# 1183
# 1744
# 0.404168090195
#
# n = 500
# 1215
# 1712
# 0.415100785787
#
# n = 1000
# 1205
# 1722
# 0.411684318415
#
# fold = 1
#
# n = 5
# 1089
# 1816
# 0.37487091222
#
# n = 10
# 1157
# 1748
# 0.398278829604
#
# n = 50
# 1173
# 1732
# 0.403786574871
#
# n = 100
# 1197
# 1708
# 0.412048192771
#
# n = 500
# 1219
# 1686
# 0.419621342513
#
# n = 1000
# 1212
# 1693
# 0.417211703959
